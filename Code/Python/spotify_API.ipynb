# %%
import requests
import json
from config import api_key
from pprint import pprint
# api_key = 'BQAfRHq6SVAOzy-5MflbHGOA1uyOQ38VXJXX3pFB-_HnAckecMGLAVn2tRjMgCfwXkbAtRi-zlF5HBEBTbnD0vl3DAFdjJzy4ZAyeugDgcR-V7SPNtliyWAs47dU76Wcm6ut5tVzKQdoPtcjJMjS'

# %%
api_key
# Out:
# 'BQC-goXwca90AKLLbxi_F_TlUiuMbVPj_yCGObUEjKR4-H_lEw5S-OgVtOjNIBULbsDU2M4GziNUXdOpO1Mrrd7rJdHd9vc9tksJnQEfCJOUGJ3unUY2QxBsxqApnksmu2uHkSPw-6xNHGlebck0'

# %% [markdown]
# SPOTIFY DOCUMENTATION
# https://developer.spotify.com/console/tracks/

# %%
# EXAMPL: GET https://api.spotify.com/v1/tracks/{id}
url = "https://api.spotify.com/v1/tracks/"
# api_key = "&apikey=" + api_key

# %%
import requests
from requests.structures import CaseInsensitiveDict

url = "https://api.spotify.com/v1/tracks/"
song_id = "7lmeHLHBe4nmXzuXc0HDjk"
query_url = f"{url}{song_id}"

headers = CaseInsensitiveDict()
headers["Accept"] = "application/json"
headers["Authorization"] = f"Bearer {api_key}"


resp = requests.get(query_url, headers=headers)

# print(resp.status_code)

resp.json()

# print(response['popularity'])

# print(api_key)
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2d0hyoQ5ynDBnkvAbJKORj'},
#     'href': 'https://api.spotify.com/v1/artists/2d0hyoQ5ynDBnkvAbJKORj',
#     'id': '2d0hyoQ5ynDBnkvAbJKORj',
#     'name': 'Rage Against The Machine',
#     'type': 'artist',
#     'uri': 'spotify:artist:2d0hyoQ5ynDBnkvAbJKORj'}],
#   'available_markets': ['AD',
#    'AE',
#    'AG',
#    'AL',
#    'AM',
#    'AO',
#    'AR',
#    'AT',
#    'AU',
#    'AZ',
#    'BA',
#    'BB',
#    'BD',
#    'BE',
#    'BF',
#    'BG',
#    'BH',
#    'BI',
#    'BJ',
#    'BN',
#    'BO',
#    'BR',
#    'BS',
#    'BT',
#    'BW',
#    'BY',
#    'BZ',
#    'CA',
#    'CH',
#    'CI',
#    'CL',
#    'CM',
#    'CO',
#    'CR',
#    'CV',
#    'CW',
#    'CY',
#    'CZ',
#    'DE',
#    'DJ',
#    'DK',
#    'DM',
#    'DO',
#    'DZ',
#    'EC',
#    'EE',
#    'EG',
#    'ES',
#    'FI',
#    'FJ',
#    'FM',
#    'FR',
#    'GA',
#    'GB',
# ...

# %% [markdown]
# Example: wk06, 02, 07

# %%
#[create list of songs from database to query]

song_ids = ['7lmeHLHBe4nmXzuXc0HDjk','1wsRitfRRtWyEapl0q22o8'] #,'1hR0fIFK2qRG3f3RF70pb7'

# %%
temp = resp.json()

# %%
temp['popularity']
# Out:
# 65

# %%
# set up lists to hold reponse info
popularity = []


url = "https://api.spotify.com/v1/tracks/"
# song_id = "7lmeHLHBe4nmXzuXc0HDjk"
# query_url = f"{url}{song_id}"

headers = CaseInsensitiveDict()
headers["Accept"] = "application/json"
headers["Authorization"] = f"Bearer {api_key}"


# Loop through the list of songs and perform a request for data on each
for song in song_ids:
    resp = requests.get(query_url, headers=headers)
    response = requests.get(url + song, headers=headers).json()
    popularity.append(response['popularity'])

    # sleep
    
    print(f"Song popularity for {song}: {popularity}")
# Out:
# Song popularity for 7lmeHLHBe4nmXzuXc0HDjk: [65]
# Song popularity for 1wsRitfRRtWyEapl0q22o8: [65, 69]

# %%
# create a data frame from data
song_dict = {
    "song_id": song_ids,
    "popularity": popularity
}
new_song_data = pd.DataFrame(song_dict)
song_dict
