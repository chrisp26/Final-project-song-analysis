# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy.stats as st

# %%
songs_csv = "../../Resources/merged_songs_data.csv"
songs_df = pd.read_csv(songs_csv, index_col=0)
songs_df.head()
# Out:
# C:\Users\chrispenn\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#                        id  danceability  energy  key  loudness  mode  \
# 0  7lmeHLHBe4nmXzuXc0HDjk         0.470   0.978    7    -5.399     1
# 1  1wsRitfRRtWyEapl0q22o8         0.599   0.957   11    -5.764     1
# 2  1hR0fIFK2qRG3f3RF70pb7         0.315   0.970    7    -5.424     1
# 3  2lbASgTSoDO7MTuLAXlTW0         0.440   0.967   11    -5.830     0
# 4  1MQTmpYOZ6fcMQc56Hdo7T         0.426   0.929    2    -6.729     1
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0727       0.02610          0.000011    0.3560    0.503  117.906
# 1       0.1880       0.01290          0.000071    0.1550    0.489  103.680
# 2       0.4830       0.02340          0.000002    0.1220    0.370  149.749
# ...

# %%
# Danceability vs Energy
plt.scatter(songs_df.iloc[:,1],songs_df.iloc[:,2], s=1, alpha=0.1, c='yellowgreen')
plt.xlabel('Danceability')
plt.ylabel('Energy')
plt.savefig('../../Images/energy_v_danceability.png',dpi=100)
plt.show()

# %%
# Accousticness vs Liveness
plt.scatter(songs_df.iloc[:,6],songs_df.iloc[:,8], s=1, alpha=0.1, c='yellowgreen')
plt.xlabel('Acousticness')
plt.ylabel('Liveness')
plt.savefig('../../Images/accousticness_v_liveness.png',dpi=100)
plt.show()

# %%
# Danceability vs Valence
plt.scatter(songs_df.iloc[:,2],songs_df.iloc[:,7], s=1, alpha=0.1, c='yellowgreen')
plt.xlabel('Accousticness')
plt.ylabel('Energy')
plt.savefig('../../Images/accousticness_v_energy.png',dpi=100)
plt.show()

# %%
# Danceability vs Valence
plt.scatter(songs_df.iloc[:,4],songs_df.iloc[:,7], s=1, alpha=0.1, c='yellowgreen')
plt.xlabel('Loudness')
plt.ylabel('Energy')
plt.savefig('../../Images/loudness_v_energy.png',dpi=100)
plt.show()

# %%
import seaborn as sns
corr = songs_df.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

plt.savefig('../..Images/correlations_2.png')

# %%
corr = songs_df.corr()
corr.style.background_gradient(cmap='coolwarm')
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True
corr[mask] = np.nan
(corr
 .style
 .background_gradient(cmap='coolwarm', axis=None, vmin=-1, vmax=1)
 .highlight_null(null_color='#f1f1f1')  # Color NaNs grey
 .set_precision(2))
 
# plt.savefig('../correlations.png')
# Out:
# <style  type="text/css" >
# ...
